# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append(r"C:\Users\S.Leśniak\Desktop\software\model_BDI\BDI_project\src")

from database import merge_db_data #type: ignore
from preprocessing import serie_mapping #type: ignore
from model import model #type: ignore
from visualization import plot_model_3d, plot_przekroj_2D #type: ignore

# %%
df_surface, df_orient, df_boreholes, df_przekroje_z_otworami, df_otwory_z_litologia = merge_db_data()
rzeczne_list, zwietrzelina_list, rzeczne_org_1, rzeczne_org_2, color_map = serie_mapping(df_surface)
# Out:
# S_top_101
# S_top_2001
# S_top_2002
# S_top_201
# S_top_202
# S_top_203
# S_top_204
# S_top_205
# S_top_206
# S_top_207
# S_top_208
# S_top_2101
# S_top_2102
# S_top_2103
# S_top_301

# %%
model = model(
    df_surface=df_surface,
    df_orient=df_orient, 
    zwietrzelina_list=zwietrzelina_list, 
    rzeczne_list=rzeczne_list, 
    rzeczne_org_1=rzeczne_org_1, 
    rzeczne_org_2=rzeczne_org_2, 
    color_map=color_map
    )

# import pickle

# with open("geomodel.pkl", "wb") as f:
#     pickle.dump(model, f)
# Out:
# Setting Backend To: AvailableBackends.PYTORCH
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 9 chunks
# Chunking done: 9 chunks
# Chunking done: 30 chunks
# Chunking done: 26 chunks
# Chunking done: 8 chunks
# Chunking done: 6 chunks
# Chunking done: 6 chunks
# Chunking done: 29 chunks
# Chunking done: 7 chunks

# %%
plot_model_3d(geo_model, df_przekroje_z_otworami, df_boreholes, df_surface=df_surface, df_orient=df_orient) #type: ignore
# Out:
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x15299deda90_21&reconnect=auto" class="pyvi…

# %%
plot_model_3d(model, df_przekroje_z_otworami, df_boreholes, nazwa_przekroju="p_1", df_surface=df_surface, df_orient=df_orient) #type: ignore
# Out:
# umm
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x1520a6d3c90_12&reconnect=auto" class="pyvi…

# %%
import gempy_viewer as gpv

gpv.plot_3d(model)
# Out:
# c:\Users\S.Leśniak\Desktop\software\model_BDI\bdi_venv\Lib\site-packages\gempy_viewer\modules\plot_3d\drawer_surfaces_3d.py:38: PyVistaDeprecationWarning:
# c:/Users/S.Leśniak/Desktop/software/model_BDI/bdi_venv/Lib/site-packages/gempy_viewer/modules/plot_3d/drawer_surfaces_3d.py:38: Argument 'color' must be passed as a keyword argument to function 'BasePlotter.add_mesh'.
# From version 0.50, passing this as a positional argument will result in a TypeError.
#   gempy_vista.surface_actors[element.name] = gempy_vista.p.add_mesh(

# %%
import pickle
import gempy_viewer as gpv
import os

with open(r"geomodel.pkl", "rb") as f:
    geo_model = pickle.load(f)

# %%
plot_model_3d(geo_model, df_przekroje_z_otworami, df_boreholes, df_surface=df_surface, df_orient=df_orient) #type: ignore
# Out:
# umm
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x1520a70cc50_9&reconnect=auto" class="pyvis…

# %%
for nazwa, punkty in df_przekroje_z_otworami.groupby("nazwa_przekroju"):
    plot_przekroj_2D(geo_model, punkty, color_map=color_map, df_otwory_z_litologia=df_otwory_z_litologia) #type: ignore
# Out:
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x152235b9f10_1&reconnect=auto" class="pyvis…
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x15206080f90_2&reconnect=auto" class="pyvis…
# Widget(value='<iframe src="http://localhost:51205/index.html?ui=P_0x1520a625d10_3&reconnect=auto" class="pyvis…
