# %%
import sys
sys.path.append(r"D:\Programy experymentalne\BDI_model_3D\BDI_project\src")
from database import *
from preprocessing import *
from model import *
from visualization import *
# Out:
# Setting Backend To: AvailableBackends.numpy

# %%
df_surface, df_orient, df_boreholes, df_przekroje_z_otworami = merge_db_data()
zwietrzelina_list, rzeczne_list, rzeczne_org_1, rzeczne_org_2, color_map = serie_mapping(df_surface)
# model(df_surface, df_orient, zwietrzelina_list, rzeczne_list, rzeczne_org_1, rzeczne_org_2, color_map)
# Out:
# S_top_101
# S_top_2001
# S_top_2002
# S_top_201
# S_top_202
# S_top_203
# S_top_204
# S_top_205
# S_top_206
# S_top_207
# S_top_208
# S_top_2101
# S_top_2102
# S_top_2103
# S_top_301
# #a5d76e :  ['S_top_101']
# #c49dee :  ['S_top_201', 'S_top_202', 'S_top_203', 'S_top_204', 'S_top_205', 'S_top_206', 'S_top_207', 'S_top_208']
# #00c3ff :  ['S_top_2001', 'S_top_2002']
# #ffffaf :  ['S_top_2101', 'S_top_2102', 'S_top_2103']
# #4bff91 :  ['S_top_301']

# %%
import pickle
import gempy_viewer as gpv
import os

with open(r"D:\Programy experymentalne\BDI_model_3D\BDI_project\notebooks\geo_model.pkl", "rb") as f:
    geo_model = pickle.load(f)

os.chdir(r"C:\temp")
